# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
excel_file_path = '2021_final_bps_dataset.xlsx'

# %%
df = pd.read_excel(excel_file_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15232 entries, 0 to 15231
# Data columns (total 58 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Sector                                                         15232 non-null  object
#  1   Subsector                                                      15232 non-null  object
#  2   Organization                                                   15232 non-null  object
#  3   Property Name                                                  15232 non-null  object
#  4   Primary Property Type - Self Selected                          15232 non-null  object
#  5   Portfolio Manager Property ID                                  15232 non-null  int64
#  6   Portfolio Manager Parent Property ID                           15232 non-null  object
# ...

# %%
df
# Out:
#               Sector      Subsector  \
# 0          Municipal   Municipality
# 1          Municipal   Municipality
# 2          Municipal   Municipality
# 3          Municipal   Municipality
# 4          Municipal   Municipality
# ...              ...            ...
# 15227  School Boards  School Boards
# 15228  School Boards  School Boards
# 15229  School Boards  School Boards
# 15230  School Boards  School Boards
# 15231  School Boards  School Boards
#
#                                             Organization  \
# 0                 The Corporation of the City of Markham
# 1                 The Corporation of the City of Markham
# 2                 The Corporation of the City of Markham
# 3                 The Corporation of the City of Markham
# 4                 The Corporation of the City of Markham
# ...                                                  ...
# 15227  Conseil scolaire de district catholique du Cen...
# 15228  Conseil scolaire de district catholique du Cen...
# ...

# %%
df2 = df[['Site Energy Use (GJ)',	'Source Energy Use (GJ)', 'Total (Location-Based) GHG Emissions (Metric Tons CO2e)','Total (Location-Based) GHG Emissions Intensity (kgCO2e/m²)']]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15232 entries, 0 to 15231
# Data columns (total 4 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Site Energy Use (GJ)                                        15232 non-null  object
#  1   Source Energy Use (GJ)                                      15232 non-null  object
#  2   Total (Location-Based) GHG Emissions (Metric Tons CO2e)     15232 non-null  object
#  3   Total (Location-Based) GHG Emissions Intensity (kgCO2e/m²)  15232 non-null  object
# dtypes: object(4)
# memory usage: 476.1+ KB

# %%
df['Total (Location-Based) GHG Emissions Intensity (kgCO2e/m²)'] = pd.to_numeric(df['Total (Location-Based) GHG Emissions Intensity (kgCO2e/m²)'], errors='coerce').fillna(0).astype(int)

# %%
df['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'] = pd.to_numeric(df['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'], errors='coerce').fillna(0).astype(int)

# %%
df['Electricity Use - Grid Purchase (GJ)'] = pd.to_numeric(df['Electricity Use - Grid Purchase (GJ)'], errors='coerce').fillna(0).astype(int)

# %%
df['Electricity Use - Grid Purchase (GJ)'] = pd.to_numeric(df['Electricity Use - Grid Purchase (GJ)'], errors='coerce').fillna(0).astype(int)

# %%
df['Electricity Use - Grid Purchase (kWh)'] = pd.to_numeric(df['Electricity Use - Grid Purchase (kWh)'], errors='coerce').fillna(0).astype(int)

# %%
df['Site Energy Use (GJ)'] = pd.to_numeric(df['Site Energy Use (GJ)'], errors='coerce').fillna(0).astype(int)

# %%
df['Weather Normalized Site Energy Use (GJ)'] = pd.to_numeric(df['Site Energy Use (GJ)'], errors='coerce').fillna(0).astype(int)

# %%
df['Weather Normalized Source Energy Use (GJ)'] = pd.to_numeric(df['Source Energy Use (GJ)'], errors='coerce').fillna(0).astype(int)

# %%
df['Source Energy Use (GJ)'] = pd.to_numeric(df['Source Energy Use (GJ)'], errors='coerce').fillna(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15232 entries, 0 to 15231
# Data columns (total 58 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Sector                                                         15232 non-null  object
#  1   Subsector                                                      15232 non-null  object
#  2   Organization                                                   15232 non-null  object
#  3   Property Name                                                  15232 non-null  object
#  4   Primary Property Type - Self Selected                          15232 non-null  object
#  5   Portfolio Manager Property ID                                  15232 non-null  int64
#  6   Portfolio Manager Parent Property ID                           15232 non-null  object
# ...

# %%
sector_stats = df.groupby('Sector').agg({'Sector': 'count', 'Total (Location-Based) GHG Emissions Intensity (kgCO2e/m²)': ['sum', 'mean']})

# Rename the columns for clarity
sector_stats.columns = ['Count', 'Sum of GHG Emissions', 'Average GHG Emissions']

# Calculate Average Rent
sector_stats['Average GHG Emissions'] = sector_stats['Sum of GHG Emissions'] / sector_stats['Count']

print("Sector Statistics")
print(sector_stats)
# Out:
# Sector Statistics
#                  Count  Sum of GHG Emissions  Average GHG Emissions
# Sector
# Municipal         9783               7486800             765.286722
# Postsecondary      340                 17748              52.200000
# Public Hospital    258                 18098              70.147287
# School Boards     4851                123038              25.363430

# %%
plt.figure(figsize=(10, 6))
sector_stats['Average GHG Emissions'].plot(kind='bar')
plt.title('Average GHG Emissions')
plt.xlabel('Sector Classification')
plt.ylabel('GHG Emissions')
plt.xticks(rotation=45)
plt.show()

# %%
subsector_stats = df.groupby('Subsector').agg({'Subsector': 'count', 'Total (Location-Based) GHG Emissions Intensity (kgCO2e/m²)': ['sum', 'mean']})

# Rename the columns for clarity
subsector_stats.columns = ['Count', 'Sum of GHG Emissions', 'Average GHG Emissions']

# Calculate Average Rent
subsector_stats['Average GHG Emissions'] = subsector_stats['Sum of GHG Emissions'] / subsector_stats['Count']

print("Sub Sector Statistics")
print(subsector_stats)
# Out:
# Sub Sector Statistics
#                          Count  Sum of GHG Emissions  Average GHG Emissions
# Subsector
# Acute                       26                  1492              57.384615
# Acute/Chronic              208                 15340              73.750000
# Chronic                     24                  1266              52.750000
# College                    255                 15211              59.650980
# Municipal Service Board     64                  6935             108.359375
# Municipality              9719               7479865             769.612614
# School Boards             4851                123038              25.363430
# University                  85                  2537              29.847059

# %%
plt.figure(figsize=(10, 6))
subsector_stats['Average GHG Emissions'].plot(kind='bar')
plt.title('Average GHG Emissions')
plt.xlabel('Sub Sector Classification')
plt.ylabel('GHG Emissions')
plt.xticks(rotation=45)
plt.show()

# %%
sector_stats2 = df.groupby('Sector').agg({'Sector': 'count','Total (Location-Based) GHG Emissions (Metric Tons CO2e)': ['sum', 'mean']})

# Rename the columns for clarity
sector_stats2.columns = ['Count', 'Sum of GHG Emissions', 'Average GHG Emissions']

# Calculate Average Rent
sector_stats2['Average GHG Emissions'] = sector_stats2['Sum of GHG Emissions'] / sector_stats2['Count']

print("Sector Statistics")
print(sector_stats2)
# Out:
# Sector Statistics
#                  Count  Sum of GHG Emissions  Average GHG Emissions
# Sector
# Municipal         9783               1320699             134.999387
# Postsecondary      340                416269            1224.320588
# Public Hospital    258                564666            2188.627907
# School Boards     4851                679627             140.100392

# %%
plt.figure(figsize=(10, 6))
sector_stats2['Average GHG Emissions'].plot(kind='bar')
plt.title('Average GHG Emissions')
plt.xlabel('Sector Classification')
plt.ylabel('GHG Emissions')
plt.xticks(rotation=45)
plt.show()

# %%
subsector_stats2 = df.groupby('Subsector').agg({'Subsector': 'count', 'Total (Location-Based) GHG Emissions (Metric Tons CO2e)': ['sum', 'mean']})

# Rename the columns for clarity
subsector_stats2.columns = ['Count', 'Sum of GHG Emissions', 'Average GHG Emissions']

# Calculate Average Rent
subsector_stats2['Average GHG Emissions'] = subsector_stats2['Sum of GHG Emissions'] / subsector_stats2['Count']

print("Sub Sector Statistics")
print(subsector_stats2)
# Out:
# Sub Sector Statistics
#                          Count  Sum of GHG Emissions  Average GHG Emissions
# Subsector
# Acute                       26                 68789            2645.730769
# Acute/Chronic              208                452477            2175.370192
# Chronic                     24                 43400            1808.333333
# College                    255                146576             574.807843
# Municipal Service Board     64                  6874             107.406250
# Municipality              9719               1313825             135.181089
# School Boards             4851                679627             140.100392
# University                  85                269693            3172.858824

# %%
plt.figure(figsize=(10, 6))
subsector_stats2['Average GHG Emissions'].plot(kind='bar')
plt.title('Average GHG Emissions')
plt.xlabel('Sector Classification')
plt.ylabel('GHG Emissions')
plt.xticks(rotation=45)
plt.show()

# %%
site_energy_stats = df.groupby('Sector').agg({'Sector': 'count', 'Site Energy Use (GJ)': ['sum', 'mean']})

# Rename the columns for clarity
site_energy_stats .columns = ['Count', 'Sum of Energy Use', 'Average Energy Use']

# Calculate Average Rent
site_energy_stats ['Average Energy Use'] = site_energy_stats ['Sum of Energy Use'] / site_energy_stats ['Count']

print("Site Energy Statistics")
print(site_energy_stats )
# Out:
# Site Energy Statistics
#                  Count  Sum of Energy Use  Average Energy Use
# Sector
# Municipal         9783           30708589         3138.974650
# Postsecondary      340           11623624        34187.129412
# Public Hospital    258           15220486        58994.131783
# School Boards     4851           19040043         3924.972789

# %%
plt.figure(figsize=(10, 6))
site_energy_stats['Average Energy Use'].plot(kind='bar')
plt.title('Average Energy Use')
plt.xlabel('Sector Classification')
plt.ylabel('Site Energy Use')
plt.xticks(rotation=45)
plt.show()

# %%
site_energy_stats2 = df.groupby('Subsector').agg({'Subsector': 'count', 'Site Energy Use (GJ)': ['sum', 'mean']})

# Rename the columns for clarity
site_energy_stats2.columns = ['Count', 'Sum of Energy Use', 'Average Energy Use']

# Calculate Average Rent
site_energy_stats2 ['Average Energy Use'] = site_energy_stats2['Sum of Energy Use'] / site_energy_stats2['Count']

print("Site Energy Statistics")
print(site_energy_stats2)
# Out:
# Site Energy Statistics
#                          Count  Sum of Energy Use  Average Energy Use
# Subsector
# Acute                       26            1690552        65021.230769
# Acute/Chronic              208           12397815        59604.879808
# Chronic                     24            1132119        47171.625000
# College                    255            4341394        17025.074510
# Municipal Service Board     64             387226         6050.406250
# Municipality              9719           30321363         3119.802757
# School Boards             4851           19040043         3924.972789
# University                  85            7282230        85673.294118

# %%
plt.figure(figsize=(10, 6))
site_energy_stats2['Average Energy Use'].plot(kind='bar')
plt.title('Average Energy Use')
plt.xlabel('Sub Sector Classification')
plt.ylabel('Site Energy Use')
plt.xticks(rotation=45)
plt.show()

# %%
source_energy_stats = df.groupby('Sector').agg({'Sector': 'count', 'Source Energy Use (GJ)': ['sum', 'mean']})

# Rename the columns for clarity
source_energy_stats.columns = ['Count', 'Sum of Energy Use', 'Average Energy Use']

# Calculate Average Rent
source_energy_stats ['Average Energy Use'] = source_energy_stats ['Sum of Energy Use'] / source_energy_stats ['Count']

print("Source Energy Statistics")
print(source_energy_stats )
# Out:
# Source Energy Statistics
#                  Count  Sum of Energy Use  Average Energy Use
# Sector
# Municipal         9783           46275274         4730.172135
# Postsecondary      340           15679668        46116.670588
# Public Hospital    258           20475196        79361.224806
# School Boards     4851           25512740         5259.274376

# %%
plt.figure(figsize=(10, 6))
site_energy_stats['Average Energy Use'].plot(kind='bar')
plt.title('Average Energy Use')
plt.xlabel('Sector Classification')
plt.ylabel('Source Energy Use')
plt.xticks(rotation=45)
plt.show()

# %%
source_energy_stats2 = df.groupby('Subsector').agg({'Subsector': 'count', 'Source Energy Use (GJ)': ['sum', 'mean']})

# Rename the columns for clarity
source_energy_stats2.columns = ['Count', 'Sum of Energy Use', 'Average Energy Use']

# Calculate Average Rent
source_energy_stats2 ['Average Energy Use'] = source_energy_stats2 ['Sum of Energy Use'] / source_energy_stats2 ['Count']

print("Source Energy Statistics")
print(source_energy_stats2)
# Out:
# Source Energy Statistics
#                          Count  Sum of Energy Use  Average Energy Use
# Subsector
# Acute                       26            2452553        94328.961538
# Acute/Chronic              208           16574734        79686.221154
# Chronic                     24            1447909        60329.541667
# College                    255            6040648        23688.815686
# Municipal Service Board     64             664664        10385.375000
# Municipality              9719           45610610         4692.932400
# School Boards             4851           25512740         5259.274376
# University                  85            9639020       113400.235294

# %%
plt.figure(figsize=(10, 6))
source_energy_stats2['Average Energy Use'].plot(kind='bar')
plt.title('Average Energy Use')
plt.xlabel('Sub Sector Classification')
plt.ylabel('Source Energy Use')
plt.xticks(rotation=45)
plt.show()

# %%
correlation_matrix = df[['Site Energy Use (GJ)','Source Energy Use (GJ)', 'Total (Location-Based) GHG Emissions (Metric Tons CO2e)','Total (Location-Based) GHG Emissions Intensity (kgCO2e/m²)', 'Number of Buildings']].corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                                                     Site Energy Use (GJ)  \
# Site Energy Use (GJ)                                            1.000000
# Source Energy Use (GJ)                                          0.998110
# Total (Location-Based) GHG Emissions (Metric To...              0.960973
# Total (Location-Based) GHG Emissions Intensity ...              0.017243
# Number of Buildings                                             0.153014
#
#                                                     Source Energy Use (GJ)  \
# Site Energy Use (GJ)                                              0.998110
# Source Energy Use (GJ)                                            1.000000
# Total (Location-Based) GHG Emissions (Metric To...                0.956381
# Total (Location-Based) GHG Emissions Intensity ...                0.017501
# Number of Buildings                                               0.141595
#
# ...

# %%
correlation_matrix = df[['Weather Normalized Site Energy Use (GJ)' ,'Weather Normalized Source Energy Use (GJ)', 'Total (Location-Based) GHG Emissions (Metric Tons CO2e)','Total (Location-Based) GHG Emissions Intensity (kgCO2e/m²)', 'Number of Buildings']].corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                                                     Weather Normalized Site Energy Use (GJ)  \
# Weather Normalized Site Energy Use (GJ)                                            1.000000
# Weather Normalized Source Energy Use (GJ)                                          0.998110
# Total (Location-Based) GHG Emissions (Metric To...                                 0.960973
# Total (Location-Based) GHG Emissions Intensity ...                                 0.017243
# Number of Buildings                                                                0.153014
#
#                                                     Weather Normalized Source Energy Use (GJ)  \
# Weather Normalized Site Energy Use (GJ)                                              0.998110
# Weather Normalized Source Energy Use (GJ)                                            1.000000
# Total (Location-Based) GHG Emissions (Metric To...                                   0.956381
# ...

# %%
sector_stats3 = df.groupby('Largest Property Use Type').agg({'Sector': 'count', 'Total (Location-Based) GHG Emissions Intensity (kgCO2e/m²)': ['sum', 'mean']})

# Rename the columns for clarity
sector_stats3.columns = ['Count', 'Sum of GHG Emissions', 'Average GHG Emissions']

# Calculate Average Rent
sector_stats3['Average GHG Emissions'] = sector_stats3['Sum of GHG Emissions'] / sector_stats3['Count']

print("Sector Statistics")
print(sector_stats3)
# Out:
# Sector Statistics
#                                                   Count  Sum of GHG Emissions  \
# Largest Property Use Type
# Adult Education                                       5                    27
# College/University                                  157                  4510
# Convention Center                                     1                    55
# Courthouse                                            1                    36
# Data Center                                           1                     7
# Drinking Water Treatment & Distribution             596               2884686
# Energy/Power Station                                  1                    34
# Fire Station                                        875                 24166
# Fitness Center/Health Club/Gym                       76                  7358
# Heated Swimming Pool                                 74                 31188
# ...

# %%
plt.figure(figsize=(50, 20))
sector_stats3['Average GHG Emissions'].plot(kind='bar')
plt.title('Average GHG Emissions')
plt.xlabel('Sector Classification')
plt.ylabel('GHG Emissions')
plt.xticks(rotation=45)
plt.show()

# %%
sector_stats4 = df.groupby('Largest Property Use Type').agg({'Sector': 'count','Total (Location-Based) GHG Emissions (Metric Tons CO2e)': ['sum', 'mean']})

# Rename the columns for clarity
sector_stats4.columns = ['Count', 'Sum of GHG Emissions', 'Average GHG Emissions']

# Calculate Average Rent
sector_stats4['Average GHG Emissions'] = sector_stats4['Sum of GHG Emissions'] / sector_stats4['Count']

print("Sector Statistics")
print(sector_stats4)
# Out:
# Sector Statistics
#                                                   Count  Sum of GHG Emissions  \
# Largest Property Use Type
# Adult Education                                       5                     8
# College/University                                  157                325598
# Convention Center                                     1                   640
# Courthouse                                            1                   151
# Data Center                                           1                   104
# Drinking Water Treatment & Distribution             596                 34782
# Energy/Power Station                                  1                    54
# Fire Station                                        875                 15732
# Fitness Center/Health Club/Gym                       76                 11801
# Heated Swimming Pool                                 74                 10992
# ...

# %%
plt.figure(figsize=(50, 20))
sector_stats4['Average GHG Emissions'].plot(kind='bar')
plt.title('Average GHG Emissions')
plt.xlabel('Sector Classification')
plt.ylabel('GHG Emissions')
plt.xticks(rotation=45)
plt.show()

# %%
sorted_data = sorted(df['Site Energy Use (GJ)'])

# Calculate Q1, Q3
q1 = np.percentile(sorted_data, 25)
q3 = np.percentile(sorted_data, 75)

# Calculate IQR
iqr = q3 - q1

# Calculate lower and upper bounds
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Find outliers
outliers = [x for x in sorted_data if x < lower_bound or x > upper_bound]

num_outliers = len(outliers)

# Calculate the ratio of outliers to the total data
ratio_outliers_to_total = num_outliers / len(df)

print("Ratio of outliers to total data:", ratio_outliers_to_total)
print("Number of outliers:", num_outliers)
print("Outliers:", outliers)
# Out:
# Ratio of outliers to total data: 0.09506302521008403
# Number of outliers: 1448
# ...

# %%
sorted_data = sorted(df['Source Energy Use (GJ)'])

# Calculate Q1, Q3
q1 = np.percentile(sorted_data, 25)
q3 = np.percentile(sorted_data, 75)

# Calculate IQR
iqr = q3 - q1

# Calculate lower and upper bounds
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Find outliers
outliers = [x for x in sorted_data if x < lower_bound or x > upper_bound]

num_outliers = len(outliers)
# Calculate the ratio of outliers to the total data
ratio_outliers_to_total = num_outliers / len(df)

print("Ratio of outliers to total data:", ratio_outliers_to_total)
print("Number of outliers:", num_outliers)
print("Outliers:", outliers)
# Out:
# Ratio of outliers to total data: 0.09880514705882353
# Number of outliers: 1505
# ...

# %%
sorted_data = sorted(df['Total (Location-Based) GHG Emissions Intensity (kgCO2e/m²)'])

# Calculate Q1, Q3
q1 = np.percentile(sorted_data, 25)
q3 = np.percentile(sorted_data, 75)

# Calculate IQR
iqr = q3 - q1

# Calculate lower and upper bounds
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Find outliers
outliers = [x for x in sorted_data if x < lower_bound or x > upper_bound]

num_outliers = len(outliers)
# Calculate the ratio of outliers to the total data
ratio_outliers_to_total = num_outliers / len(df)

print("Ratio of outliers to total data:", ratio_outliers_to_total)
print("Number of outliers:", num_outliers)
print("Outliers:", outliers)
# Out:
# Ratio of outliers to total data: 0.0741202731092437
# Number of outliers: 1129
# ...

# %%
sorted_data = sorted(df['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'])

# Calculate Q1, Q3
q1 = np.percentile(sorted_data, 25)
q3 = np.percentile(sorted_data, 75)

# Calculate IQR
iqr = q3 - q1

# Calculate lower and upper bounds
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Find outliers
outliers = [x for x in sorted_data if x < lower_bound or x > upper_bound]

num_outliers = len(outliers)
# Calculate the ratio of outliers to the total data
ratio_outliers_to_total = num_outliers / len(df)

print("Ratio of outliers to total data:", ratio_outliers_to_total)
print("Number of outliers:", num_outliers)
print("Outliers:", outliers)
# Out:
# Ratio of outliers to total data: 0.08692226890756302
# Number of outliers: 1324
# ...

# %%
df2.describe()
# Out:
#        Site Energy Use (GJ) Source Energy Use (GJ)  \
# count                 15232                  15232
# unique                10709                  11289
# top           Not Available          Not Available
# freq                   1805                   1805
#
#        Total (Location-Based) GHG Emissions (Metric Tons CO2e)  \
# count                                               15232
# unique                                               3211
# top                                         Not Available
# freq                                                 1753
#
#        Total (Location-Based) GHG Emissions Intensity (kgCO2e/m²)
# count                                               15232
# unique                                               1740
# top                                         Not Available
# freq                                                 2459

# %%
from scipy import stats

mean = np.mean(df['Site Energy Use (GJ)'])

# Calculate median
median = np.median(df['Site Energy Use (GJ)'])

# Calculate mode
mode = stats.mode(df['Site Energy Use (GJ)'])

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
# Out:
# Mean: 5028.41005777311
# Median: 844.0
# Mode: ModeResult(mode=0, count=1982)

# %%
def remove_outliers(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    df_filtered = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df_filtered

# Remove outliers from column 'B'
df_cleaned = remove_outliers(df,'Site Energy Use (GJ)')

# Calculate mean, median, and mode of column 'B' after removing outliers
mean_B = df_cleaned['Site Energy Use (GJ)'].mean()
median_B = df_cleaned['Site Energy Use (GJ)'].median()
mode_B = stats.mode(df_cleaned['Site Energy Use (GJ)'])

print("Mean of column B after removing outliers:", mean_B)
print("Median of column B after removing outliers:", median_B)
print("Mode of column B after removing outliers:", mode_B)
# Out:
# Mean of column B after removing outliers: 1354.2379570516541
# Median of column B after removing outliers: 572.0
# Mode of column B after removing outliers: ModeResult(mode=0, count=1982)

# %%
from scipy import stats

mean = np.mean(df['Source Energy Use (GJ)'])

# Calculate median
median = np.median(df['Source Energy Use (GJ)'])

# Calculate mode
mode = stats.mode(df['Source Energy Use (GJ)'])

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
# Out:
# Mean: 7086.58600315126
# Median: 1214.5
# Mode: ModeResult(mode=0, count=1956)

# %%
def remove_outliers(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    df_filtered = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df_filtered

# Remove outliers from column 'B'
df_cleaned = remove_outliers(df,'Source Energy Use (GJ)')

# Calculate mean, median, and mode of column 'B' after removing outliers
mean_B = df_cleaned['Source Energy Use (GJ)'].mean()
median_B = df_cleaned['Source Energy Use (GJ)'].median()
mode_B = stats.mode(df_cleaned['Source Energy Use (GJ)'])

print("Mean of column B after removing outliers:", mean_B)
print("Median of column B after removing outliers:", median_B)
print("Mode of column B after removing outliers:", mode_B)
# Out:
# Mean of column B after removing outliers: 1856.9036206017338
# Median of column B after removing outliers: 817.0
# Mode of column B after removing outliers: ModeResult(mode=0, count=1956)
